# %% [markdown]
# # Pequeña introducción a la creación de clases en Python

# %% [markdown]
# A continuación se presenta información sobre cómo crear clases y cómo utilizar sus métodos y atributos. Para profundizar más en la Programación Orientada a Objetos en Python, se puede consultar:
# - [Programación Orientada a Objetos en Python - Documentación oficial](https://docs.python.org/es/3/tutorial/classes.html)

# %% [markdown]
# ## Una clase simple

# %% [markdown]
# A continuación se presenta una clase que guarda información de un estudiante:

# %%
class Student:
    def __init__(self, name, grade=None):
        self.name = name
        self.grade = grade

# %% [markdown]
# Esta clase tiene una función especial, `__init__()`, que se llama automáticamente cuando se crea una instancia de la clase.
#
# El argumento `self` se refiere al objeto que se va a crear, y apunta a la memoria que el objeto usará para almacenar el contenido de la clase.

# %%
a = Student("Mike")
print(a.name)
print(a.grade)
# Out:
# Mike
# None

# %% [markdown]
# A continuación se crean varios estudiantes y se almacenan en una lista:

# %%
students = []
students.append(Student("fry", "F-"))
students.append(Student("leela", "A"))
students.append(Student("zoidberg", "F"))
students.append(Student("hubert", "C+"))
students.append(Student("bender", "B"))
students.append(Student("calculon", "C"))
students.append(Student("amy", "A"))
students.append(Student("hermes", "A"))
students.append(Student("scruffy", "D"))
students.append(Student("flexo", "F"))
students.append(Student("morbo", "D"))
students.append(Student("hypnotoad", "A+"))
students.append(Student("zapp", "Q"))

# %% [markdown]
# ````{admonition} Ejercicio Rápido
#
# Recorre la lista `students` e imprime el nombre y la nota de cada estudiante, uno por línea.
#
# ````

# %% [markdown]
# Se puede usar comprensión de listas con la lista de objetos. Por ejemplo, encontremos todos los estudiantes que tienen una calificación que comienza con "A":

# %%
As = [q.name for q in students if q.grade.startswith("A")]
As
# Out:
# ['leela', 'amy', 'hermes', 'hypnotoad']

# %% [markdown]
# ## Cartas de Juego

# %% [markdown]
# A continuación se presenta una clase más compleja que representa una carta de juego. Obsérvese que se utiliza Unicode para representar los palos.

# %%
class Card:
    
    def __init__(self, suit=1, rank=2):
        if suit < 1 or suit > 4:
            print("palo inválido, estableciendo a 1")
            suit = 1
            
        self.suit = suit
        self.rank = rank
        
    def value(self):
        """ queremos ordenar principalmente por rango y luego por palo """
        return self.suit + (self.rank-1)*14
    
    # incluimos esto para permitir comparaciones con < y > entre cartas
    def __lt__(self, other):
        return self.value() < other.value()

    def __eq__(self, other):
        return self.rank == other.rank and self.suit == other.suit
    
    def __repr__(self):
        return self.__str__()
    
    def __str__(self):
        suits = [u"\u2660",  # picas
                 u"\u2665",  # corazones
                 u"\u2666",  # diamantes
                 u"\u2663"]  # tréboles
        
        r = str(self.rank)
        if self.rank == 11:
            r = "J"
        elif self.rank == 12:
            r = "Q"
        elif self.rank == 13:
            r = "K"
        elif self.rank == 14:
            r = "A"
                
        return r +':'+suits[self.suit-1]

# %% [markdown]
# Se puede crear una carta fácilmente:

# %%
c1 = Card()

# %% [markdown]
# Se pueden pasar argumentos a `__init__` cuando se crea la instancia de la clase:

# %%
c2 = Card(suit=2, rank=2)

# %% [markdown]
# Una vez que se tiene el objeto, se puede acceder a cualquiera de las funciones (métodos) de la clase usando el operador punto (`.`):

# %%
c2.value()
# Out:
# 16

# %%
c3 = Card(suit=0, rank=4)
# Out:
# palo inválido, estableciendo a 1

# %% [markdown]
# El método especial `__str__` convierte el objeto en una cadena que puede ser impresa:

# %%
print(c1)
print(c2)
# Out:
# 2:♠
# 2:♥

# %% [markdown]
# El método `value` asigna un valor al objeto que puede ser usado en comparaciones, y el método especial `__lt__` es el que realiza la comparación cuando se usa el operador `<`:

# %%
print(c1 > c2)
print(c1 < c2)
# Out:
# False
# True

# %% [markdown]
# Nótese que no todos los operadores están definidos para esta clase, por lo que, por ejemplo, no se pueden sumar dos cartas:

# %%
c1 + c2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 c1 + c2
#
# TypeError: unsupported operand type(s) for +: 'Card' and 'Card'

# %% [markdown]
# ````{admonition} Ejercicio Rápido
#
#  * Crea una "mano" correspondiente a una escalera (5 cartas de cualquier palo, pero en secuencia de rango)
#  * Crea otra mano correspondiente a un color (5 cartas todas del mismo palo, de cualquier rango)
#  * Finalmente crea una mano con una de las cartas duplicada. Esto no debería estar permitido en una baraja estándar de cartas. ¿Cómo se podría comprobar esto?
#
# ````

# %% [markdown]
# ## Operadores

# %% [markdown]
# Se pueden definir operaciones como `+` y `-` para que funcionen con objetos personalizados. A continuación se presenta un ejemplo simple de una clase `Currency` que mantiene un registro del país y la cantidad:

# %%
class Currency:
    """ una clase simple para manejar moneda extranjera """
    
    def __init__(self, amount, country="US"):
        self.amount = amount
        self.country = country
        
    def __add__(self, other):
        return Currency(self.amount + other.amount, country=self.country)

    def __sub__(self, other):
        return Currency(self.amount - other.amount, country=self.country)

    def __str__(self):
        return f"{self.amount} {self.country}"

# %% [markdown]
# Ahora se pueden crear algunas cantidades monetarias para diferentes países:

# %%
d1 = Currency(10, "US")
d2 = Currency(15, "US")
print(d2 - d1)
# Out:
# 5 US

# %% [markdown]
# ````{admonition} Ejercicio Rápido
#
# Tal como está escrita, la clase `Currency` tiene un error: no comprueba si las cantidades están en el mismo país antes de sumarlas. Modifica el método `__add__` para que primero compruebe si los países son los mismos. Si lo son, devuelve el nuevo objeto `Currency` con la suma; si no, devuelve `None`.
# ````

# %% [markdown]
# ## <span class="fa fa-star"></span> Ejemplo de Vectores
#
# Aquí escribimos una clase para representar vectores 2-d. Los vectores tienen una dirección y una magnitud. Podemos representarlos como un par de números, que representan las longitudes x e y. Internamente usaremos una tupla para esto.
#
# Queremos que nuestra clase haga todas las operaciones básicas que hacemos con vectores: sumarlos, multiplicar por un escalar, producto vectorial, producto escalar, devolver la magnitud, etc.
#
# Usaremos el módulo math para proporcionar algunas funciones básicas que podríamos necesitar (como sqrt)
#
# Este ejemplo nos mostrará cómo sobrecargar las operaciones estándar en python. Aquí hay una lista de los métodos incorporados:
#
# https://docs.python.org/3/reference/datamodel.html
#
# Para que quede muy claro qué se está llamando y cuándo, he añadido prints en cada una de las funciones

# %%
import math

# %%
class Vector:
    """ un vector bidimensional general """
    
    def __init__(self, x, y):
        print("en __init__")
        self.x = x
        self.y = y
        
    def __str__(self):
        print("en __str__")        
        return f"({self.x} î + {self.y} ĵ)"
    
    def __repr__(self):
        print("en __repr__")        
        return f"Vector({self.x}, {self.y})"

    def __add__(self, other):
        print("en __add__")        
        if isinstance(other, Vector):
            return Vector(self.x + other.x, self.y + other.y)
        else:
            # no tiene sentido sumar algo que no sean dos vectores
            print(f"no sabemos cómo sumar un {type(other)} a un Vector")
            raise NotImplementedError

    def __sub__(self, other):
        print("en __sub__")        
        if isinstance(other, Vector):
            return Vector(self.x - other.x, self.y - other.y)
        else:
            # no tiene sentido restar algo que no sean dos vectores
            print(f"no sabemos cómo restar un {type(other)} a un Vector")
            raise NotImplementedError

    def __mul__(self, other):
        print("en __mul__")        
        if isinstance(other, int) or isinstance(other, float):
            # la multiplicación escalar cambia la magnitud
            return Vector(other*self.x, other*self.y)
        else:
            print("no sabemos cómo multiplicar dos Vectores")
            raise NotImplementedError

    def __matmul__(self, other):
        print("en __matmul__")
        # un producto escalar
        if isinstance(other, Vector):
            return self.x*other.x + self.y*other.y
        else:
            print("multiplicación matricial no definida")
            raise NotImplementedError

    def __rmul__(self, other):
        print("en __rmul__")        
        return self.__mul__(other)

    def __truediv__(self, other):
        print("en __truediv__")        
        # solo sabemos cómo multiplicar por un escalar
        if isinstance(other, int) or isinstance(other, float):
            return Vector(self.x/other, self.y/other)

    def __abs__(self):
        print("en __abs__")        
        return math.sqrt(self.x**2 + self.y**2)

    def __neg__(self):
        print("en __neg__")        
        return Vector(-self.x, -self.y)

    def cross(self, other):
        # un producto vectorial -- devolvemos la magnitud, ya que estará
        # en la dirección z, pero solo somos 2-d 
        return abs(self.x*other.y - self.y*other.x)

# %% [markdown]
# Esta es una clase básica que proporciona dos métodos `__str__` y `__repr__` para mostrar una representación de ella.
#
# La convención es que `__str__` es legible por humanos mientras que `__repr__` debería ser una forma que pueda usarse para recrear el objeto (por ejemplo, a través de `eval()`). Ver:
#
# http://stackoverflow.com/questions/1436703/difference-between-str-and-repr-in-python

# %%
v = Vector(1,2)
v
# Out:
# en __init__
# en __repr__
# Vector(1, 2)

# %%
print(v)
# Out:
# en __str__
# (1 î + 2 ĵ)

# %% [markdown]
# Los vectores tienen una longitud, y usaremos la función incorporada `abs()` para proporcionar la magnitud. Para un vector:
#
# $$\vec{v} = \alpha \hat{i} + \beta \hat{j}$$
#
# tenemos
#
# $$|\vec{v}| = \sqrt{\alpha^2 + \beta^2}$$

# %%
abs(v)
# Out:
# en __abs__
# 2.23606797749979

# %% [markdown]
# Veamos ahora las operaciones matemáticas con vectores. Queremos poder sumar y restar dos vectores así como multiplicar y dividir por un escalar.

# %%
u = Vector(3,5)
# Out:
# en __init__

# %%
w = u + v
print(w)
u - v
# Out:
# en __add__
# en __init__
# en __str__
# (4 î + 7 ĵ)
# en __sub__
# en __init__
# en __repr__
# Vector(2, 3)

# %% [markdown]
# No tiene sentido sumar un escalar a un vector, así que no implementamos esto -- ¿qué ocurre?

# %%
u + 2.0
# Out:
# en __add__
# no sabemos cómo sumar un <class 'float'> a un Vector
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 u + 2.0
#
# Cell In[22], line 24, in Vector.__add__(self, other)
#      21 else:
#      22     # no tiene sentido sumar algo que no sean dos vectores
#      23     print(f"no sabemos cómo sumar un {type(other)} a un Vector")
# ---> 24     raise NotImplementedError
#
# NotImplementedError:

# %% [markdown]
# Ahora multiplicación. Tiene sentido multiplicar por un escalar, pero hay múltiples formas de definir la multiplicación de dos vectores.
#
# Ten en cuenta que Python proporciona tanto una función `__mul__` como una `__rmul__` para definir qué ocurre cuando multiplicamos un vector por una cantidad y qué ocurre cuando multiplicamos otra cosa por un vector.

# %%
u*2.0
2.0*u
# Out:
# en __mul__
# en __init__
# en __rmul__
# en __mul__
# en __init__
# en __repr__
# Vector(6.0, 10.0)

# %%
u/5.0
# Out:
# en __truediv__
# en __init__
# en __repr__
# Vector(0.6, 1.0)

# %% [markdown]
# y división: `__truediv__` es la forma de Python 3 de división `/`, mientras que `__floordiv__` es la forma antigua de Python 2, también habilitada a través de `//`.
#
# Dividir un escalar por un vector no tiene sentido:

# %%
5.0/u
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 5.0/u
#
# TypeError: unsupported operand type(s) for /: 'float' and 'Vector'

# %% [markdown]
# Python 3.5 introdujo un nuevo operador de multiplicación matricial, `@` -- lo usaremos para implementar un producto escalar entre dos vectores:

# %%
u @ v
# Out:
# en __matmul__
# 13

# %% [markdown]
# Para un producto vectorial, no tenemos un operador obvio, así que usaremos una función. Para vectores 2-d, esto resultará en un escalar

# %%
u.cross(v)
# Out:
# 1

# %% [markdown]
# Finalmente, la negación es una operación separada:

# %%
-u
# Out:
# en __neg__
# en __init__
# en __repr__
# Vector(-3, -5)
