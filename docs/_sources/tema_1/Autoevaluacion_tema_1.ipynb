# %% [markdown]
# # Autoevaluación rápida - Tema 1
#
# Responde las siguientes preguntas para evaluar tu comprensión de los conceptos del Tema 1.

# %%
from jupyterquiz import display_quiz

# %%
preguntas = [
    {
        "question": "¿Qué función de Python se usa para convertir una cadena a entero?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "str()", "correct": False, "feedback": "str() convierte a cadena, no a entero."},
            {"answer": "int()", "correct": True, "feedback": "¡Correcto! int() convierte valores a enteros."},
            {"answer": "float()", "correct": False, "feedback": "float() convierte a números decimales."},
            {"answer": "cast()", "correct": False, "feedback": "cast() no es una función estándar de Python."}
        ]
    },
    {
        "question": "¿Qué operador se usa en Python para obtener el resto de una división?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "/", "correct": False, "feedback": "/ es el operador de división normal."},
            {"answer": "//", "correct": False, "feedback": "// es el operador de división entera."},
            {"answer": "%", "correct": True, "feedback": "¡Correcto! % es el operador módulo (resto)."},
            {"answer": "mod", "correct": False, "feedback": "mod no es un operador en Python."}
        ]
    },
    {
        "question": "¿Qué función se usa para leer entrada del usuario por consola?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "read()", "correct": False, "feedback": "read() no es la función estándar para entrada por consola."},
            {"answer": "input()", "correct": True, "feedback": "¡Correcto! input() lee datos del usuario."},
            {"answer": "get()", "correct": False, "feedback": "get() no es una función estándar de entrada."},
            {"answer": "scanf()", "correct": False, "feedback": "scanf() es de C, no de Python."}
        ]
    },
    {
        "question": "¿Qué módulo de Python contiene funciones trigonométricas como sin() y cos()?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "numpy", "correct": False, "feedback": "numpy también las tiene, pero no es el módulo estándar básico."},
            {"answer": "math", "correct": True, "feedback": "¡Correcto! El módulo math contiene funciones matemáticas básicas."},
            {"answer": "trig", "correct": False, "feedback": "No existe un módulo estándar llamado trig."},
            {"answer": "scipy", "correct": False, "feedback": "scipy es para cálculos científicos avanzados."}
        ]
    },
    {
        "question": "En la fórmula de Haversine, ¿en qué unidades deben estar las coordenadas para los cálculos trigonométricos?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "Grados", "correct": False, "feedback": "Las funciones trigonométricas de Python usan radianes."},
            {"answer": "Radianes", "correct": True, "feedback": "¡Correcto! Debes convertir de grados a radianes con math.radians()."},
            {"answer": "Gradianes", "correct": False, "feedback": "Los gradianes no se usan comúnmente en Python."},
            {"answer": "Da igual", "correct": False, "feedback": "La unidad sí importa para los cálculos correctos."}
        ]
    }
]

display_quiz(preguntas, shuffle_answers=True)

# %% [markdown]
# # Autoevaluación rápida - Tema 1
#
# Responde las siguientes preguntas para evaluar tu comprensión de los conceptos del Tema 1.
#
# ```{tip}
# **Ejecuta el código interactivamente:**
# Haz clic en el botón 🚀 (cohete) en la parte superior de la página y selecciona "Live Code" para ejecutar el quiz directamente en tu navegador con Thebe.
# ```

# %%
from jupyterquiz import display_quiz

# %%
preguntas = [
    {
        "question": "¿Qué función de Python se usa para convertir una cadena a entero?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "str()", "correct": False, "feedback": "str() convierte a cadena, no a entero."},
            {"answer": "int()", "correct": True, "feedback": "¡Correcto! int() convierte valores a enteros."},
            {"answer": "float()", "correct": False, "feedback": "float() convierte a números decimales."},
            {"answer": "cast()", "correct": False, "feedback": "cast() no es una función estándar de Python."}
        ]
    },
    {
        "question": "¿Qué operador se usa en Python para obtener el resto de una división?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "/", "correct": False, "feedback": "/ es el operador de división normal."},
            {"answer": "//", "correct": False, "feedback": "// es el operador de división entera."},
            {"answer": "%", "correct": True, "feedback": "¡Correcto! % es el operador módulo (resto)."},
            {"answer": "mod", "correct": False, "feedback": "mod no es un operador en Python."}
        ]
    },
    {
        "question": "¿Qué función se usa para leer entrada del usuario por consola?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "read()", "correct": False, "feedback": "read() no es la función estándar para entrada por consola."},
            {"answer": "input()", "correct": True, "feedback": "¡Correcto! input() lee datos del usuario."},
            {"answer": "get()", "correct": False, "feedback": "get() no es una función estándar de entrada."},
            {"answer": "scanf()", "correct": False, "feedback": "scanf() es de C, no de Python."}
        ]
    },
    {
        "question": "¿Qué módulo de Python contiene funciones trigonométricas como sin() y cos()?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "numpy", "correct": False, "feedback": "numpy también las tiene, pero no es el módulo estándar básico."},
            {"answer": "math", "correct": True, "feedback": "¡Correcto! El módulo math contiene funciones matemáticas básicas."},
            {"answer": "trig", "correct": False, "feedback": "No existe un módulo estándar llamado trig."},
            {"answer": "scipy", "correct": False, "feedback": "scipy es para cálculos científicos avanzados."}
        ]
    },
    {
        "question": "En la fórmula de Haversine, ¿en qué unidades deben estar las coordenadas para los cálculos trigonométricos?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "Grados", "correct": False, "feedback": "Las funciones trigonométricas de Python usan radianes."},
            {"answer": "Radianes", "correct": True, "feedback": "¡Correcto! Debes convertir de grados a radianes con math.radians()."},
            {"answer": "Gradianes", "correct": False, "feedback": "Los gradianes no se usan comúnmente en Python."},
            {"answer": "Da igual", "correct": False, "feedback": "La unidad sí importa para los cálculos correctos."}
        ]
    }
]

display_quiz(preguntas, shuffle_answers=True)
# Out:
# <div id="uDrRVtvluxxz" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #uDrRVtvluxxz {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# ...
